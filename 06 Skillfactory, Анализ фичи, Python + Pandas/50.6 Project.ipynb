# %% [markdown]
# ---
# # **50.6 PROJECT**
# # Выполнен студентом группы SDA-170 Голомбовским Николаем
# ---
# ---
# ВНИМАНИЕ! ВНИМАНИЕ! ВНИМАНИЕ!
#
# Срезу предупреждаю, что решение данного проекта является НЕ СТАНДАРТНЫМ!!!
# Это для того, чтобы проверяющий сразу понимал к чему нужно готовиться. :-)
#
# Очевидно, что подобное изменение учебного задания требует с моей стороны, как минимум, пояснения - почему я так решил сделать?
# Вот именно этим я и займусь сразу в следующем текстовом блоке...
#
# ---

# %% [markdown]
# ## -1. Вбоквел - мои мысли относительного данного проекта

# %% [markdown]
# **Что вызывает у меня некоторое недоумение в последнее время во время учёбы в Skilldactory?**
#
# **1. Количество подаваемой информации в учебных блоках.**
# Что я имею в виду?
# Вначале при изучении Python на один учебный блок давалась информация типа, "типы переменных", "списки" и т.д.
# Сейчас же нам даётся, примерно, по библиотеке в неделю.
# Не знаю, как обстоят дела у других студентов Skillfactory, но у меня подобная "скорость" обучения вызывает некотрую оторопь - лично мне НЕ хватает времени, чтобы более менее разобраться в вопросе, поэкспериментировать и чему то научиться. В результате у меня идёт отставание от учебного плана, рассчитанного Skillfactory для моего обучения на курсе "Аналитика данных".
# Лично я не считаю это проблемой - я пришёл в Skillfactory за знаниями и некоторым опытом. Поэтому для меня именно это является первоочередной задачей, а не "укладывание" в график учёбы. :-)
#
# **2. С другой стороны я понимаю позицию Skillfactory.**
# Программирование на Python сегодня - это огромаднейшая предметная область. И, как нам объясняли в самих учебных материалах, а особенно если посмотреть видосики на Ютубе от программеров Pyhon, - если человек считает себя КРУТЫМ специалистом по всем аспектам Python, то этот человек ГАРАНТИРОВАННО НЕ является таковым.
# Сегодня сам язык Python оброс сумасшедшим количеством самых разных библиотек, програмных оболочек, интеграций в иные програмные пакеты. В результате всё это НЕ СПОСОБЕН знать ни один человек. Можно только иметь некоторое представление и с помощью инета уметь искать конкретные решения для стоящих перед программистом Python задач.
# Именно поэтому, как мне кажется, я и понимаю Skillfactory, которая старается вложить в наши головы как можно больше обзорных знаний по самым разным вопросам, имеющим отношение к Python, и в дополнение даёт готовые блоки програмного РАБОТАЮЩЕГО и ФУНКЦИОНИРУЮЩЕГО кода.
# Другими словами, Skillfactory НЕ пытается сделать из нас супер-мега готовых программистов по Python, а старается научить нас методике написания работающего кода на Python.
# Вот за это лично от меня самый низкий поклон руководству и всем сотрудникам Skillfactory!
#
# **3. "Шкурный" интерес Skillfactory.**
# Помимо всего прочего Skillfactory является коммерческой организацией. Другими словами, она должна приносить прибыль своим акционерам (о которых мы знаем благодаря тому самому Ютубу, ну а так же и о других онлайн школах, которые принадлежат тем же самым владельцам).
# Плюс имейте в виде, что за последние полгода в развитие Skillfactory и её рекламу вложены весьма приличные деньги и количество усилий! Например, реклама обучающих курсов Skillfactory только, наверное, не звучит пока ещё из утюга - в других местах она уже отметилась. :-)
# Соответственно, все эти вложения сделаны с расчётом на существенное увеличение прибыли, что возможно для онлайн-школы благодаря постоянного росту студентов.
#
# **4. Реализация "шкурных" интересов Skillfactory, имеющая отношения к нам, студентам.**
# Уверен, что у читателя данного "сочинения" уже давно зародился вопрос - а какое отношение имеет всё вышеприведённое к обучению в Skillfactory, а особенно в данному проекту?
# Уже близко, надо всего лишь "ещё самую чуточку потерпеть". :-)
# Одним из довольно важных показателей по оценке эффективности работы всего Skillfactory является количество студентов, которые заканчивают данную онлайн-школу.
# Я много раз пытался получить точные цифры как по количеству студентов, так и по количеству дошедших до конца обучения. Но, как оказалось, данная информация относится к коммерческой и её можно получить либо опосредованно, либо их рекламных материалов, которые Skillfactory распространяет о себе.
# Почему я вновь поднимаю вопрос о количестве студентов, доведшие своё обучение в Skillfactory до конца?
# Просто Skillfactory, как мне кажется, слишком старается помочь в учёбе таким "близким к выпуску" студентам. Что я имею в виду?
# - Вы не обращали внимание, что на более менее сложные вопросы в учебных блоках, Skillfactory в конце этих самых учебных блоков приводит правильные решения. С одной стороны, это делается для того, чтобы нам помочь в обучении. Но с другой, это можно трактовать и как "пинание нас под одно место" только чтобы мы даже НЕ думали бросать учёбу в Skillfactory. :-)
# - Затем берём эти самые проекты, которые нам нужно выполнить и выложить их на всеобщее обозрение. С одной стороны, это для того, чтобы мы научились легко читать и понимать код других людей. С другой, это можно рассматривать как то же самое "пинание нас под одно место" с той же целью. Например, по данному заданию №50.6 вообще приводится ссылка на эталонное решение этого задания в самом учебном блоке!
# - Не знаю как обстоит ситуация у других, но меня лично никто из Skillfactory не "ругает" за отставание от графика обучения (чему я, конечно же, только рад). :-) В качестве "оправдания" скажу, что я стараюсь тратить всё имеющееся у меня свободное время на последние учебные блоки и довести своё обучение до вручения диплома. Но этого не достаточно, чтобы держаться в графике обучения. :-(
# - Я не поленился, залез в Пачку и попытался оценить количество студентов, которые ГАРНТИРОВАННО выполняли задания "on_demand_1", "on_demand_2" и финальный "project_4". Напомню, что наш переход на Пачку состоялся примерно 14 марта и с тех пор прошло 2,5 месяца. Итак, берём студентов-аналитиков и "компьютерных мозгоправов" - это те, информацию о которых я вижу в Пачке. У меня получилось, что в Пачке за это время отписались 8 человек по заданию "on_demand_1", 3 человека по "on_demand_2" и 16 человек задавали вопросы по "project_4". Я понимаю, что это несколько заниженные цифры по количеству "почти выпускников" в данных учебных направлениях. Но, как мне кажется, если приведённые цифры и отличаются от реальности, то уж точно не в разы.
# - Надеюсь, что не открую секретную информацию Skillfactory, если напишу следующее. В Пачке в моей группе SDA-170 сейчас записано 11 человек. Из них только 6 являются постоянными пользователями Пачки, а остальные 5 коллег - им было выслано приглашение на вступление в Пачку, но они это приглашение не реализовали. Переводя на русский язык, можно сказать что чуть меньше половины студентов нашей группы бросили обучение в Skillfactory.

# %% [markdown]
# **Ну и наконец то, какое отношение это имеет к выполнению задания №50.6?**
#
# Какие пути решения данного задания я вижу?
# 1. Тупо взять эталлоное решение от Skillfactory или скачать из Пачки одно из решений других студентов, внести мелкие исправления в код (хотя бы по иному назвать переменные и датафреймы) и выложить итоговый код в Пачку как собственное выстраданное решение. :-)
# 2. Честно попытаться самостоятельно решить данное задание. Если по ходу будут вопросы - задать из в Пачке кураторам. По окончании сверить свою работу с эталонной и парой работ от других студентов. Если нужно внести несколько изменений и выложить итоговый результат в Пачку для оценки.
# 3. Как нибудь проявить себя при выполнении задания по одному из предыдущих направлений решения - добавить что-то от себя.
#
# **Каким же путём идти мне?**
# Как говорит народная русская пословица, мы трудностей не ищем - мы их сами создаём!
# Посему я решил сделать следующее:
# - Я с самого начала скачал эталонное решение от Skillfactory и разобрался в его решении.
# - Так же сразу скачал из Пачки две последние работы по данному заданию других студентов. Однакомился с их решениями то же.
# - Решил сконцентрировать свои усилия при работе над данным заданием в направлении №3 - добавить в работу что-то такое, чего я не увидел в других работах. Всё таки, в первую очередь мы аналитики, то есть должны быть способны находить неочевидное в устоявшемся. Вычленить это, провести обработку, визуализировать и предложить результаты тем, кому может быть полезной подобная точка зрения.

# %% [markdown]
# **Структура моего выполнения задания №50.6**
#
# 1. Вначале я написал текст, который Вы только что прочитали. Почему бы уже не посчитать это в качестве некой самостоятельной работы в рамках данного проекта и имеющей отношение к аналитике (или Вы так не считаете)? :-)
# 2. Далее, я тупо скопировал ЭТАЛОННОЕ решение данного задания от компании Skillfactory. Ну если САМ! Skillfactory считает это решение эталонным, то оно должно гарантированно пройти по всем оценкам данного задания. Это типа я намекаю, что мне нужно поставить все 4 балла за его выполнение. :-) Не дай Бог я не получу все 4 балла за этот проект - тут же напишу кляузу на имя генерального директора с тем, что в его Skillfactory притесняют студентов и искусственно занижают баллы за проекты. :-) С другой стороны, перечитайте, пожалуйста, формулировку данного задания - там сказано что нам самостоятельно нужно получить определённые параметры. Ну так я ведь САМ эти параметры получил, честно скопировав результаты с эталонной работы! Ведь НЕ СКАЗАНО же, что всю работу я должен выполнить именно сам! :-)
# 3. А вот далее я постараюсь уйти в свободный аналитический поиск. Я попытаюсь найти интересные срезы, которые имеют отношение к стоящей задаче в рамках данного задания, и проведу соответствующие анализ/визуализации. Хочется верить, что проверящий данное задание сочтёт эту мою работу СТОЯЩЕЙ ОЦЕНКИ. ПЛИЗЗЗЗ... Ведь в первую очередь мы должны стать хорошими АНАЛИТИКАМИ, ну а уже отличное знание аналитических инструментов - это на втором месте. :-) Или я не прав?!

# %% [markdown]
# ## 0. Постановка задачи

# %% [markdown]
# **ЛЕГЕНДА**
#
# Возвращаемся к нашей клининговой компании.
# На календаре — 31 мая, и ваша большая команда готовится к релизу. К вам приходит с просьбой один из РО (англ. Product owner, «владелец продукта») — новенький сотрудник, который очень любит шутить. А также — увы! — совершенно не разбирается в метриках.
#
# **ЦЕЛЬ**
#
# Итак, мы выяснили необходимую информацию, подсветили все нюансы (что, признаться честно, было не так уж и легко) и теперь чётко понимаем, что же от нас требуется. А именно:
# - Посчитать долю пользователей, листавших ленту, Retention Rate и ARPPU до и после внедрения фичи.
# - Сформировать выводы по анализу.
#
# **Работаем!**

# %% [markdown]
# **ЗАДАНИЕ**
#
# Настало время самостоятельной работы! Вам предстоит сделать следующее:
# 1. Посчитать показатели Retention Rate седьмого дня и ARPPU за два периода: до и после внедрения фичи.
# 2. Сформировать выводы по анализу.
#
# Далее вы можете отправить ссылку на файл Jupyter Notebook одногруппникам и, в свою очередь, оставить фидбек на чужую работу. Кроме того, вы можете свериться с эталонным ответом — он находится под кнопкой в конце юнита.

# %% [markdown]
# **КРИТЕРИИ ОЦЕНКИ**
#
# 1. Отсутствие ошибок: ноутбук открывается без ошибок.
# >1 балл за безошибочный ответ.
#
# 2. Retention Rate седьмого дня: показатель рассчитан для периода до и после внедрения фичи.
# >1 балл за верно рассчитанный показатель.
#
# 3. ARPPU: показатель рассчитан для периода до и после внедрения фичи.
# >1 балл за верно рассчитанный показатель.
#
# 4. Представлены выводы, сделанные на основе анализа.
# >1 балл за описание выводов.

# %% [markdown]
# ## 1. Эталонное решение от Skillfactory + одно моё личное замечание

# %% [markdown]
# 1. Для понимания эффективности новой фичи нужно посчитать показатели Retention 7 дня  и ARPPU за два периода: до и после внедрения фичи
#
# 2. Сформировать выводы по анализу

# %% [markdown]
# 1. Считаем Retention 7 дня за период до релиза (май 2019). Чтобы посчитать retention не для одной даты, а для всего периода, необходимо разделить сумму по столбцу "7 день" для всех входящих в период когорт и разделить на сумму по столбцу "зарегистрировано клиентов" для этих же когорт.

# %%
 #! pip install psycopg2

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import psycopg2
import psycopg2.extras 

import json 
import requests
from pprint import pprint

import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff

# %% [markdown]
# Создаем датафрейм с retention за весь период (до и после релиза) и сразу рассчитываем lifetime для каждой строки

# %%
def getRegisteredUsersCount():
    query = '''SELECT r.registration_date, count(distinct(r.user_id)) as registered_users_count
    FROM case9.registration r
    WHERE r.registration_date >= '2019-05-01' and r.registration_date < '2019-07-01'
    GROUP BY 1
    '''.format()
    conn = psycopg2.connect("dbname='skillfactory' user='skillfactory' host='84.201.134.129' password='cCkxxLVrDE8EbvjueeMedPKt' port=5432")
    dict_cur = conn.cursor(cursor_factory=psycopg2.extras.DictCursor)
    dict_cur.execute(query)
    rows = dict_cur.fetchall()
    data = []
    for row in rows:
        data.append(dict(row))
    return data

registered_users_count = pd.DataFrame(getRegisteredUsersCount())
registered_users_count['registration_date'] = pd.to_datetime(registered_users_count['registration_date'])
def getActiveUsersCountWithCohorts():
    query = '''SELECT ac.activity_date, r.registration_date, count(distinct(ac.user_id)) as active_users_count
    FROM case9.user_activity ac
    LEFT JOIN case9.registration r ON r.user_id = ac.user_id
    WHERE r.registration_date >= '2019-05-01' and r.registration_date < '2019-07-01'
    GROUP BY 1,2
    '''.format()
    conn = psycopg2.connect("dbname='skillfactory' user='skillfactory' host='84.201.134.129' password='cCkxxLVrDE8EbvjueeMedPKt' port=5432")
    dict_cur = conn.cursor(cursor_factory=psycopg2.extras.DictCursor)
    dict_cur.execute(query)
    rows = dict_cur.fetchall()
    data = []
    for row in rows:
        data.append(dict(row))
    return data

active_users_count_with_cohorts = pd.DataFrame(getActiveUsersCountWithCohorts())
for col in ['activity_date','registration_date']:
    active_users_count_with_cohorts[col] = pd.to_datetime(active_users_count_with_cohorts[col])
retention_table = active_users_count_with_cohorts.merge(registered_users_count,on=['registration_date'],how='left')
retention_table['lifetime'] = retention_table['activity_date'] - retention_table['registration_date']
retention_table['lifetime'] = retention_table['lifetime']/np.timedelta64(1,'D')
retention_table['lifetime'] = retention_table['lifetime'].astype(int) # Приведем тип к целому числу
retention_table
# Out:
#      activity_date registration_date  active_users_count  \
# 0       2019-05-01        2019-05-01                2590
# 1       2019-05-02        2019-05-01                2146
# 2       2019-05-02        2019-05-02                2049
# 3       2019-05-03        2019-05-01                1637
# 4       2019-05-03        2019-05-02                1817
# ...            ...               ...                 ...
# 1886    2019-07-28        2019-06-29                 129
# 1887    2019-07-28        2019-06-30                 198
# 1888    2019-07-29        2019-06-29                  89
# 1889    2019-07-29        2019-06-30                 144
# 1890    2019-07-30        2019-06-30                  91
#
#       registered_users_count  lifetime
# 0                       6516         0
# 1                       6516         1
# 2                       5309         0
# 3                       6516         2
# 4                       5309         1
# ...                      ...       ...
# ...

# %%
# Этот код добавил я уже сам для проверки одной гипотезы...
retention_table['lifetime'].value_counts(sort=True)
# Out:
# 0     61
# 16    61
# 29    61
# 28    61
# 27    61
# 26    61
# 25    61
# 24    61
# 23    61
# 22    61
# 21    61
# 20    61
# 19    61
# 18    61
# 17    61
# 15    61
# 1     61
# 14    61
# 13    61
# 12    61
# 11    61
# 10    61
# 9     61
# 8     61
# 7     61
# 6     61
# 5     61
# 4     61
# 3     61
# 2     61
# 30    61
# Name: lifetime, dtype: int64

# %% [markdown]
# **Что же именно я хотел проверить данным кодом?**
#
# Простую вещь.
# В учебную базу данных внесена информация ТОЛЬКО по 30 дням активности пользователя со дня регистрации этого пользователя.
# Как видно из данных, для каждого из 61 дня (с 1 мая по 30 июня включительно) у нас поле 'lifetime' в датафрейме "retention_table" принимает знаечение от 0 до 30.
#
# Почему только до 30?
# Если посмотреть учебные материалы, а именно на распредление Retension Rate для разных когорт в зависимости от lifetime, то можно увидеть, что на 30 день lifetime, Retension Rate принимает значение 2-3%. Другими словами, нам и имеющихся данных выше крыши для выполнения задания. Но даже если было бы больше данных, то что принципиально новое мы могли бы получить и узнать? :-)
#
# На самом деле, меня больше волнует ответ на такой вопрос.
# Для lifetime=0, Retension Rate варьируется от 33% до 40%.
# Перевожу "на русский" - после регистрации на сайте ТОЛЬКО 33-40% пользователей переходят на сам сайт и делают что-то там интересное и полезное, типа проявляют РЕГИСТРИРУЕМУЮ активность.
# Честно говоря, я ожидал что эта цифра будет близкой к 100% - типа пользователь зарегистрировался и тут же пошёл шляться по самому сайту.
# Конечно, могут быть случаи, когда после регистрации, пользователя отвлекли и только в последующие дни он/она вернулся на сайт. Но, блин, не 60% же таких должно быть!
# Можно, конечно, проверить по id пользователей - все ли зарегистрировавшиеся проявляли активность на сайте в один из последующих 30 дней. Задача, несомненно, интересная, но как то меня ломает её выполнять. :-)

# %% [markdown]
# Добавляем к этой таблице данные по доходам

# %%
def getRevenue():
    query = '''SELECT re.date, r.registration_date, count(distinct(re.user_id)) as users_count_with_revenue, sum(re.revenue) as revenue
    FROM case9.user_revenue re
    LEFT JOIN case9.registration r ON r.user_id = re.user_id
    WHERE r.registration_date >= '2019-05-01' and r.registration_date < '2019-07-01'
    GROUP BY 1,2
    '''.format()
    conn = psycopg2.connect("dbname='skillfactory' user='skillfactory' host='84.201.134.129' password='cCkxxLVrDE8EbvjueeMedPKt' port=5432")
    dict_cur = conn.cursor(cursor_factory=psycopg2.extras.DictCursor)
    dict_cur.execute(query)
    rows = dict_cur.fetchall()
    data = []
    for row in rows:
        data.append(dict(row))
    return data

revenue = pd.DataFrame(getRevenue())

# %%
revenue.sort_values(by=['registration_date', 'date'])
# Out:
#             date registration_date  users_count_with_revenue     revenue
# 0     2019-05-01        2019-05-01                      1672  2357.58000
# 1     2019-05-02        2019-05-01                      1420   514.67900
# 3     2019-05-03        2019-05-01                      1048   390.95200
# 6     2019-05-04        2019-05-01                       931   260.13600
# 10    2019-05-05        2019-05-01                       835   233.09400
# ...          ...               ...                       ...         ...
# 1730  2019-07-24        2019-06-30                       142     5.60661
# 1733  2019-07-25        2019-06-30                       132     2.98796
# 1738  2019-07-26        2019-06-30                       118     5.43194
# 1743  2019-07-29        2019-06-30                       100    10.05400
# 1744  2019-07-30        2019-06-30                        63    11.50500
#
# [1745 rows x 4 columns]

# %%
for col in ['date','registration_date']:
    revenue[col] = pd.to_datetime(revenue[col])

# %%
revenue = revenue.rename(columns={'date':'activity_date'})
retention_table_with_revenue = retention_table.merge(revenue,on=['registration_date','activity_date'],how='left')
retention_table_with_revenue
# Out:
#      activity_date registration_date  active_users_count  \
# 0       2019-05-01        2019-05-01                2590
# 1       2019-05-02        2019-05-01                2146
# 2       2019-05-02        2019-05-02                2049
# 3       2019-05-03        2019-05-01                1637
# 4       2019-05-03        2019-05-02                1817
# ...            ...               ...                 ...
# 1886    2019-07-28        2019-06-29                 129
# 1887    2019-07-28        2019-06-30                 198
# 1888    2019-07-29        2019-06-29                  89
# 1889    2019-07-29        2019-06-30                 144
# 1890    2019-07-30        2019-06-30                  91
#
#       registered_users_count  lifetime  users_count_with_revenue     revenue
# 0                       6516         0                    1672.0  2357.58000
# 1                       6516         1                    1420.0   514.67900
# ...

# %%
retention_table_with_revenue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1891 entries, 0 to 1890
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   activity_date             1891 non-null   datetime64[ns]
#  1   registration_date         1891 non-null   datetime64[ns]
#  2   active_users_count        1891 non-null   int64
#  3   registered_users_count    1891 non-null   int64
#  4   lifetime                  1891 non-null   int32
#  5   users_count_with_revenue  1745 non-null   float64
#  6   revenue                   1745 non-null   float64
# dtypes: datetime64[ns](2), float64(2), int32(1), int64(2)
# memory usage: 110.8 KB

# %%
for col in ['revenue','users_count_with_revenue']:
    retention_table_with_revenue[col] = retention_table_with_revenue[col].fillna(0)
retention_table_with_revenue['users_count_with_revenue'] = retention_table_with_revenue['users_count_with_revenue'].astype(int)
retention_table_with_revenue
# Out:
#      activity_date registration_date  active_users_count  \
# 0       2019-05-01        2019-05-01                2590
# 1       2019-05-02        2019-05-01                2146
# 2       2019-05-02        2019-05-02                2049
# 3       2019-05-03        2019-05-01                1637
# 4       2019-05-03        2019-05-02                1817
# ...            ...               ...                 ...
# 1886    2019-07-28        2019-06-29                 129
# 1887    2019-07-28        2019-06-30                 198
# 1888    2019-07-29        2019-06-29                  89
# 1889    2019-07-29        2019-06-30                 144
# 1890    2019-07-30        2019-06-30                  91
#
#       registered_users_count  lifetime  users_count_with_revenue     revenue
# 0                       6516         0                      1672  2357.58000
# 1                       6516         1                      1420   514.67900
# ...

# %% [markdown]
# Теперь у нас есть общий датафрейм, можем выполнять расчеты. Фильтруем таблицу по retention 7 дня для пользователей, привлеченных до релиза (май 2019)

# %%
retention_7_may_table = retention_table_with_revenue[retention_table_with_revenue['lifetime']==7][retention_table_with_revenue['registration_date']>="2019-05-01"][retention_table_with_revenue['registration_date']<"2019-06-01"]
retention_7_may_table
# Out:
# C:\Users\Ferrick\AppData\Local\Temp\ipykernel_17104\3629413038.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   retention_7_may_table = retention_table_with_revenue[retention_table_with_revenue['lifetime']==7][retention_table_with_revenue['registration_date']>="2019-05-01"][retention_table_with_revenue['registration_date']<"2019-06-01"]
#     activity_date registration_date  active_users_count  \
# 28     2019-05-08        2019-05-01                 953
# 37     2019-05-09        2019-05-02                 745
# 47     2019-05-10        2019-05-03                 895
# 58     2019-05-11        2019-05-04                1186
# 70     2019-05-12        2019-05-05                1358
# 83     2019-05-13        2019-05-06                 985
# 97     2019-05-14        2019-05-07                 851
# 112    2019-05-15        2019-05-08                 883
# 128    2019-05-16        2019-05-09                 767
# ...

# %% [markdown]
# Выполняем расчет retention 7 дня для этих когорт

# %%
retention_7_may = retention_7_may_table['active_users_count'].sum() / retention_7_may_table['registered_users_count'].sum()
print(retention_7_may)
# Out:
# 0.12933000957960866

# %% [markdown]
# Получается, что retention 7 дня для пользователей, привлеченных до релиза = 12,9%
# Теперь делаем аналогичный расчет для июня

# %%
retention_7_june_table = retention_table_with_revenue[retention_table_with_revenue['lifetime']==7][retention_table_with_revenue['registration_date']>="2019-06-01"][retention_table_with_revenue['registration_date']<"2019-07-01"]
retention_7_june_table
# Out:
# C:\Users\Ferrick\AppData\Local\Temp\ipykernel_17104\3603262186.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   retention_7_june_table = retention_table_with_revenue[retention_table_with_revenue['lifetime']==7][retention_table_with_revenue['registration_date']>="2019-06-01"][retention_table_with_revenue['registration_date']<"2019-07-01"]
#      activity_date registration_date  active_users_count  \
# 736     2019-06-08        2019-06-01                 545
# 767     2019-06-09        2019-06-02                 683
# 798     2019-06-10        2019-06-03                 484
# 829     2019-06-11        2019-06-04                 511
# 860     2019-06-12        2019-06-05                 472
# 891     2019-06-13        2019-06-06                 460
# 922     2019-06-14        2019-06-07                 385
# 953     2019-06-15        2019-06-08                 424
# 984     2019-06-16        2019-06-09                 610
# ...

# %%
retention_7_june = retention_7_june_table['active_users_count'].sum() / retention_7_june_table['registered_users_count'].sum()
print(retention_7_june)
# Out:
# 0.12560867530346634

# %% [markdown]
# Retention 7 дня в июне составляет 12,6%. Это незначительно, но все же ниже, чем в период до релиза.
# Теперь расчитаем ARPPU до и после (считаем средний доход именно на платящих клиентов, поэтому делить будем на 'users_count_with_revenue')

# %%
may_arppu = retention_table_with_revenue['revenue'][retention_table_with_revenue['registration_date']>="2019-05-01"][retention_table_with_revenue['registration_date']<"2019-06-01"].sum() / retention_table_with_revenue['users_count_with_revenue'][retention_table_with_revenue['registration_date']>="2019-05-01"][retention_table_with_revenue['registration_date']<"2019-06-01"].sum()
print(may_arppu)
# Out:
# 0.3061245846810113

# %%
retention_table_with_revenue[(retention_table_with_revenue['registration_date']>="2019-05-01") & (retention_table_with_revenue['registration_date']<"2019-06-01")]['revenue'].sum() / retention_table_with_revenue[(retention_table_with_revenue['registration_date']>="2019-05-01") & (retention_table_with_revenue['registration_date']<"2019-06-01")]['users_count_with_revenue'].sum()
# Out:
# 0.3061245846810113

# %% [markdown]
# В мае, до релиза, ARPPU = 0,3 у.е. Теперь считаем июнь:

# %%
june_arppu = retention_table_with_revenue['revenue'][retention_table_with_revenue['registration_date']>="2019-06-01"][retention_table_with_revenue['registration_date']<"2019-07-01"].sum() / retention_table_with_revenue['users_count_with_revenue'][retention_table_with_revenue['registration_date']>="2019-06-01"][retention_table_with_revenue['registration_date']<"2019-07-01"].sum()
print(june_arppu)
# Out:
# 0.39319399168570485

# %% [markdown]
# Похоже, что в июне средний доход с 1 платящего клиента вырос относительно мая и составляет 0,4 у.е.

# %% [markdown]
# Выводы:
# * Retention 7 дня остался примерно на прежнем уровне
# * Тем не менее ARPPU в июне вырос на 30%
#
# Возможно, на ARPPU могли повлиять и другие факторы. Чтобы убедиться в этом, необходимо было бы провести раскатку функционала на часть пользователей и/или провести анализ с учетом фактора использования конкретно нашей фичи, однако таких данных, как это часто бывает, у нас нет. Здесь явно имеет смысл настроить сбор таких данных на будущее, но на текущий момент и в текущих условиях можно сказать, что наша фича оказалась вполне эффективна. Во всяком случае, ARPPU она не обрушила, а значит можно оставлять ее на проде.

# %% [markdown]
# ## 2. Фууу. С обязаловкой закончили.
# ## Сейчас можно поискать какие-нибудь аналитические вкусности...

# %% [markdown]
# ### 2.1 А не посмотреть ли нам на регистрации новых пользователей?

# %%
# Подготовим датасеты для визуализации
line_data_may = retention_table_with_revenue[(retention_table_with_revenue['registration_date']>="2019-05-01") & (retention_table_with_revenue['registration_date']<"2019-06-01")]
line_data_may_new_users = line_data_may.groupby('registration_date')['registered_users_count'].max().reset_index()

line_data_june = retention_table_with_revenue[(retention_table_with_revenue['registration_date']>="2019-06-01") & (retention_table_with_revenue['registration_date']<"2019-07-01")]
line_data_june_new_users = line_data_june.groupby('registration_date')['registered_users_count'].max().reset_index()


# А сейчас это на экран
fig = go.Figure()

fig.add_trace(trace = go.Scatter(
    x=line_data_may_new_users.index + 1,
    y=line_data_may_new_users['registered_users_count'],
    name='К-во зарегистрированных пользователей в МАЕ',
    mode='lines+markers'
))

fig.add_trace(trace = go.Scatter(
    x=line_data_june_new_users.index + 1,
    y=line_data_june_new_users['registered_users_count'],
    name='К-во зарегистрированных пользователей в ИЮНЕ',
    mode='lines+markers'
))

fig.update_layout(title='К-во новых пользователей по дням месяца', height=500, width=1400)
fig.show()

# %%
print('Падение количества НОВЫХ пользователей в ИЮНЕ по сравнению с МАЕМ:', 
      round( (line_data_june_new_users['registered_users_count'].sum() / line_data_may_new_users['registered_users_count'].sum() - 1 ) * 100, 2) )
# Out:
# Падение количества НОВЫХ пользователей в ИЮНЕ по сравнению с МАЕМ: -46.85

# %% [markdown]
# **Выводы:**
#
# 1. Анализ НОВЫХ пользователей показывает, что ввод новой супер-дюпер фичы с 1 июня не привело к увеличению новых пользователей. Наоборот, наблюдается падение новых пользователей в июне почти в 2 раза (47%) по отношению к маю.
# 2. С другой стороны, так и должно быть. Ведь простое изменение главной загрузочной страницы само по себе и не должно приводить к увеличению новых пользователей - для этого нужна соответствующая рекламная кампания.
# 3. Но с другой стороны, откуда взялось падение количества новых пользователей ИМЕННО после ввода новой фияи - 1 июня?

# %% [markdown]
# ### 2.2 Посмотрим на ежедневную активность пользователей?

# %%
# Подготовим датасеты для визуализации
line_data_may2 = retention_table_with_revenue[(retention_table_with_revenue['activity_date']>="2019-05-01") & (retention_table_with_revenue['activity_date']<"2019-06-01")]
line_data_may_active_users = line_data_may2.groupby('activity_date')['active_users_count'].sum().reset_index()

line_data_june2 = retention_table_with_revenue[(retention_table_with_revenue['activity_date']>="2019-06-01") & (retention_table_with_revenue['activity_date']<"2019-07-01")]
line_data_june_active_users = line_data_june2.groupby('activity_date')['active_users_count'].sum().reset_index()


# А сейчас это на экран
fig = go.Figure()

fig.add_trace(trace = go.Scatter(
    x=line_data_may_active_users.index + 1,
    y=line_data_may_active_users['active_users_count'],
    name='К-во активных пользователей в МАЕ',
    mode='lines+markers'
))

fig.add_trace(trace = go.Scatter(
    x=line_data_june_active_users.index + 1,
    y=line_data_june_active_users['active_users_count'],
    name='К-во активных пользователей в ИЮНЕ',
    mode='lines+markers'
))

fig.update_layout(title='К-во АКТИВНЫХ пользователей по дням месяца', height=500, width=1400)
fig.show()

# %%
print('Падение количества ЕЖЕДНЕВНЫХ АКТИВНЫХ пользователей 30 ИЮНЯ по сравнению с 1 ИЮНЯ:', 
      round( (int(line_data_june_active_users[line_data_june_active_users['activity_date'] == '2019-06-30']['active_users_count']) / 
              int(line_data_june_active_users[line_data_june_active_users['activity_date'] == '2019-06-01']['active_users_count']) - 1 ) * 100, 2) )
# Out:
# Падение количества ЕЖЕДНЕВНЫХ АКТИВНЫХ пользователей 30 ИЮНЯ по сравнению с 1 ИЮНЯ: -42.12

# %% [markdown]
# **Выводы:**
#
# 1. То, что количество активных пользователей растёт в течение мая - это простое следствие алгоритма расчёта количества АКТИВНЫХ пользователей. Активных пользователей мы подключали в привязке к когортам по дате регистрации пользователей. Для большей объективности нужно было бы учитывать активность пользователей по когортам, образованным так же и в апреле - но у нас нет таких данных.
# 2. Для нашего же анализа более важным является точка 1 июня - дата появления новой фичы на сайте. И вот в июне мы наблюдаем плавное ПАДЕНИЕ активности пользователей! Это что получается - ввод новой фичи привёл к ПАДЕНИЮ активности пользователей? Если сравнить активность 30 июня с актиностью 1 июня, то падение составит 42%. Что-то тут не так и не помешало бы покапаться ещё в каких-нибудь данных чтобы понять что происходило в июне...

# %% [markdown]
# ### 2.3 Ну а сейчас глянем ка на ежедневную активность ДЕНЕЖНЫХ пользователей!

# %%
# Подготовим датасеты для визуализации
line_data_may3 = retention_table_with_revenue[(retention_table_with_revenue['activity_date']>="2019-05-01") & (retention_table_with_revenue['activity_date']<"2019-06-01")]
line_data_may_revenue_users = line_data_may3.groupby('activity_date')['users_count_with_revenue'].sum().reset_index()

line_data_june3 = retention_table_with_revenue[(retention_table_with_revenue['activity_date']>="2019-06-01") & (retention_table_with_revenue['activity_date']<"2019-07-01")]
line_data_june_revenue_users = line_data_june3.groupby('activity_date')['users_count_with_revenue'].sum().reset_index()


# А сейчас это на экран
fig = go.Figure()

fig.add_trace(trace = go.Scatter(
    x=line_data_may_revenue_users.index + 1,
    y=line_data_may_revenue_users['users_count_with_revenue'],
    name='К-во активных ДЕНЕЖНЫХ пользователей в МАЕ',
    mode='lines+markers'
))

fig.add_trace(trace = go.Scatter(
    x=line_data_june_revenue_users.index + 1,
    y=line_data_june_revenue_users['users_count_with_revenue'],
    name='К-во активных ДЕНЕЖНЫХ пользователей в ИЮНЕ',
    mode='lines+markers'
))

fig.update_layout(title='К-во АКТИВНЫХ ДЕНЕЖНЫХ пользователей по дням месяца', height=500, width=1400)
fig.show()

# %%
print('Падение количества ЕЖЕДНЕВНЫХ АКТИВНЫХ ДЕНЕЖНЫХ пользователей 30 ИЮНЯ по сравнению с 1 ИЮНЯ:', 
      round( (int(line_data_june_revenue_users[line_data_june_revenue_users['activity_date'] == '2019-06-30']['users_count_with_revenue']) / 
              int(line_data_june_revenue_users[line_data_june_revenue_users['activity_date'] == '2019-06-01']['users_count_with_revenue']) - 1 ) * 100, 2) )
# Out:
# Падение количества ЕЖЕДНЕВНЫХ АКТИВНЫХ ДЕНЕЖНЫХ пользователей 30 ИЮНЯ по сравнению с 1 ИЮНЯ: -47.89

# %% [markdown]
# **Выводы:**
#
# Кривые активности ДЕНЕЖНЫХ пользователей повторяют кривые просто активности пользователей.

# %% [markdown]
# ### 2.4 Наконец то мы посмотрим на денежки хоть одним глазком - ежедневный доход...

# %%
# Подготовим датасеты для визуализации
line_data_may4 = retention_table_with_revenue[(retention_table_with_revenue['activity_date']>="2019-05-01") & (retention_table_with_revenue['activity_date']<"2019-06-01")]
line_data_may_revenue = line_data_may4.groupby('activity_date')['revenue'].sum().reset_index()

line_data_june4 = retention_table_with_revenue[(retention_table_with_revenue['activity_date']>="2019-06-01") & (retention_table_with_revenue['activity_date']<"2019-07-01")]
line_data_june_revenue = line_data_june4.groupby('activity_date')['revenue'].sum().reset_index()


# А сейчас это на экран
fig = go.Figure()

fig.add_trace(trace = go.Scatter(
    x=line_data_may_revenue.index + 1,
    y=line_data_may_revenue['revenue'],
    name='Ежедневный суммарный доход в МАЕ',
    mode='lines+markers'
))

fig.add_trace(trace = go.Scatter(
    x=line_data_june_revenue.index + 1,
    y=line_data_june_revenue['revenue'],
    name='Ежедневный суммарный доход в ИЮНЕ',
    mode='lines+markers'
))

fig.update_layout(title='Ежедневный суммарный доход по дням месяца', height=500, width=1400)
fig.show()

# %%
print('Падение количества ЕЖЕДНЕВНЫХ АКТИВНЫХ ДЕНЕЖНЫХ пользователей 30 ИЮНЯ по сравнению с 1 ИЮНЯ:', 
      round( (line_data_june_revenue['revenue'].sum() / line_data_may_revenue['revenue'].sum() - 1 ) * 100, 2) )
# Out:
# Падение количества ЕЖЕДНЕВНЫХ АКТИВНЫХ ДЕНЕЖНЫХ пользователей 30 ИЮНЯ по сравнению с 1 ИЮНЯ: -11.24

# %% [markdown]
# **Выводы:**
#
# 1. Ежедневные доходы довольно сильно меняются от дня ко дню. Тем не менее, наблюдается плавное снижение суммарных доходов в течение июня.
# 2.  Суммарный доход в июня на 11% меньше аналогичного показателя в мае.

# %% [markdown]
# ### 2.5 Оценим суммарные доходы по когортам

# %%
# Подготовим датасеты для визуализации
line_data_may5 = retention_table_with_revenue[(retention_table_with_revenue['registration_date']>="2019-05-01") & (retention_table_with_revenue['registration_date']<"2019-06-01")]
line_data_may_revenue_by_cohort = line_data_may5.groupby('registration_date')['revenue'].sum().reset_index()

line_data_june5 = retention_table_with_revenue[(retention_table_with_revenue['registration_date']>="2019-06-01") & (retention_table_with_revenue['registration_date']<"2019-07-01")]
line_data_june_revenue_by_cohort = line_data_june5.groupby('registration_date')['revenue'].sum().reset_index()


# А сейчас это на экран
fig = go.Figure()

fig.add_trace(trace = go.Scatter(
    x=line_data_may_revenue_by_cohort.index + 1,
    y=line_data_may_revenue_by_cohort['revenue'],
    name='Суммарный доход по когортам в МАЕ',
    mode='lines+markers'
))

fig.add_trace(trace = go.Scatter(
    x=line_data_june_revenue_by_cohort.index + 1,
    y=line_data_june_revenue_by_cohort['revenue'],
    name='Суммарный доход по когортам в ИЮНЕ',
    mode='lines+markers'
))

fig.update_layout(title='Суммарный доход по когортам по дням месяца', height=500, width=1400)
fig.show()

# %%
print('Падение количества ЕЖЕДНЕВНЫХ АКТИВНЫХ ДЕНЕЖНЫХ пользователей 30 ИЮНЯ по сравнению с 1 ИЮНЯ:', 
      round( (line_data_june_revenue_by_cohort['revenue'].sum() / line_data_may_revenue_by_cohort['revenue'].sum() - 1 ) * 100, 2) )
# Out:
# Падение количества ЕЖЕДНЕВНЫХ АКТИВНЫХ ДЕНЕЖНЫХ пользователей 30 ИЮНЯ по сравнению с 1 ИЮНЯ: -34.68

# %% [markdown]
# **Выводы:**
#
# Графики явно показывают, что доходы от майских когорт превышают в среднем на 1/3 доходны от июньских когорт.

# %% [markdown]
# ### 2.6 Посмотрим на динамику ежедневного ARPU

# %%
# Подготовим датасеты для визуализации
line_data_may6 = retention_table_with_revenue[(retention_table_with_revenue['activity_date']>="2019-05-01") & (retention_table_with_revenue['activity_date']<"2019-06-01")]
line_data_may_ARPU = line_data_may6.groupby('activity_date').agg({'revenue':'sum', 'active_users_count':'sum'}).reset_index()
line_data_may_ARPU['ARPU'] = line_data_may_ARPU['revenue'] / line_data_may_ARPU['active_users_count']

line_data_june6 = retention_table_with_revenue[(retention_table_with_revenue['activity_date']>="2019-06-01") & (retention_table_with_revenue['activity_date']<"2019-07-01")]
line_data_june_ARPU = line_data_june6.groupby('activity_date').agg({'revenue':'sum', 'active_users_count':'sum'}).reset_index()
line_data_june_ARPU['ARPU'] = line_data_june_ARPU['revenue'] / line_data_june_ARPU['active_users_count']


# А сейчас это на экран
fig = go.Figure()

fig.add_trace(trace = go.Scatter(
    x=line_data_may_ARPU.index + 1,
    y=line_data_may_ARPU['ARPU'],
    name='ARPU в МАЕ',
    mode='lines+markers'
))

fig.add_trace(trace = go.Scatter(
    x=line_data_june_ARPU.index + 1,
    y=line_data_june_ARPU['ARPU'],
    name='ARPU в ИЮНЕ',
    mode='lines+markers'
))

fig.update_layout(title='ARPU по дням месяца', height=500, width=1400)
fig.show()

# %% [markdown]
# **Выводы:**
#
# 1. Значительных скачков в ARPU в июне по сравнению с маем не наблюдается.
# 2. Значительного прироста ARPU в июне ПОСЛЕ запуска фиче так же не наблюдается.
# 3. Высокие значения ARPU в первых чиислах мая я объясняю отсутствием данных за апрель месяц.

# %% [markdown]
# ### 2.7 Мы не можем пройти мимо и ежедневного ARPPU

# %%
# Подготовим датасеты для визуализации
line_data_may7 = retention_table_with_revenue[(retention_table_with_revenue['activity_date']>="2019-05-01") & (retention_table_with_revenue['activity_date']<"2019-06-01")]
line_data_may_ARPPU = line_data_may7.groupby('activity_date').agg({'revenue':'sum', 'users_count_with_revenue':'sum'}).reset_index()
line_data_may_ARPPU['ARPPU'] = line_data_may_ARPPU['revenue'] / line_data_may_ARPPU['users_count_with_revenue']

line_data_june7 = retention_table_with_revenue[(retention_table_with_revenue['activity_date']>="2019-06-01") & (retention_table_with_revenue['activity_date']<"2019-07-01")]
line_data_june_ARPPU = line_data_june7.groupby('activity_date').agg({'revenue':'sum', 'users_count_with_revenue':'sum'}).reset_index()
line_data_june_ARPPU['ARPPU'] = line_data_june_ARPPU['revenue'] / line_data_june_ARPPU['users_count_with_revenue']


# А сейчас это на экран
fig = go.Figure()

fig.add_trace(trace = go.Scatter(
    x=line_data_may_ARPPU.index + 1,
    y=line_data_may_ARPPU['ARPPU'],
    name='ARPPU в МАЕ',
    mode='lines+markers'
))

fig.add_trace(trace = go.Scatter(
    x=line_data_june_ARPPU.index + 1,
    y=line_data_june_ARPPU['ARPPU'],
    name='ARPPU в ИЮНЕ',
    mode='lines+markers'
))

fig.update_layout(title='ARPPU по дням месяца', height=500, width=1400)
fig.show()

# %% [markdown]
# **Выводы:**
#
# Чего то принципиально нового в дополнение к графикам ARPU не наблюдается. Хотя если присмотреться более внимательно, можно замтить небольшое среднее превышения ARPPU в июне по сравнению с маем начиная 8 числа месяца.

# %% [markdown]
# ### 2.8 Сравним ка Retension Rate по дням в мае и июне

# %%
# Подготовим датасеты для визуализации
line_data_may8 = retention_table_with_revenue[(retention_table_with_revenue['registration_date']>="2019-05-01") & (retention_table_with_revenue['registration_date']<"2019-06-01")]
line_data_may_rate = line_data_may8.groupby('lifetime').agg({'registered_users_count':'sum', 'active_users_count':'sum'}).reset_index()
line_data_may_rate['rate'] = line_data_may_rate['active_users_count'] / line_data_may_rate['registered_users_count']

line_data_june8 = retention_table_with_revenue[(retention_table_with_revenue['registration_date']>="2019-06-01") & (retention_table_with_revenue['registration_date']<"2019-07-01")]
line_data_june_rate = line_data_june8.groupby('lifetime').agg({'registered_users_count':'sum', 'active_users_count':'sum'}).reset_index()
line_data_june_rate['rate'] = line_data_june_rate['active_users_count'] / line_data_june_rate['registered_users_count']


# А сейчас это на экран
fig = go.Figure()

fig.add_trace(trace = go.Scatter(
    x=line_data_may_rate['lifetime'],
    y=line_data_may_rate['rate'],
    name='Retension Rate в МАЕ',
    mode='lines+markers'
))

fig.add_trace(trace = go.Scatter(
    x=line_data_june_rate['lifetime'],
    y=line_data_june_rate['rate'],
    name='Retension Rate в ИЮНЕ',
    mode='lines+markers'
))

fig.update_layout(title='Retension Rate в целом за май и июнь в зависимости от lifetime', height=500, width=1400)
fig.show()

# %% [markdown]
# **Выводы:**
#
# Уважаемый читатель, вы в таком же недоумении как и я? Типа, какого чёрта, Retension Rate в мае и июне имеют подобную идентичность?
# Такое ощущение, что здесь не обошлось без шаловливых ручёнок сотрудника Skillfactory, который готовил данные для данного задания. :-)

# %% [markdown]
# ### 2.9 Общие выводы по аналитическим вкусностям

# %% [markdown]
# **Выводы:**
#
# 1. Как то я не смог обнаружить "вау-эффекта" от введения новой фичы. Это на самом деле так или просто я плохо искал?
# 2. Наблюдается падение некоторых показателей в июне по сравнению с маем. К сожалению, имеющие данные не позволяют сделать вывод с чем это может быть связано.

# %% [markdown]
# ## 3. До скорой новой встречи в следующем задании...
